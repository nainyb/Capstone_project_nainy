# %%
import pandas as pd

# %%
US_HEV_SALES_by_model= pd.read_csv("C:/Users/nainy/Documents/nss_dda16/new_Capstone/data/New folder/US_HEV_SALES_BY_MODEL_1990_2029_Modified.csv")

# %%
US_HEV_SALES_by_model
# Out:
#                              Vehicle     1999     2000     2001     2002  \
# 0                      Honda Insight       17    3,788    4,726    2,216
# 1                       Toyota Prius   NAN       5,562   15,556   20,119
# 2                        Honda Civic   NAN      NAN      NAN      13,707
# 3        Ford Escape/Mercury Mariner   NAN      NAN      NAN      NAN
# 4                       Honda Accord   NAN      NAN      NAN      NAN
# 5                  Toyota Highlander   NAN      NAN      NAN      NAN
# 6                      Lexus RX 450h   NAN      NAN      NAN      NAN
# 7                       Toyota Camry   NAN      NAN      NAN      NAN
# 8                      Lexus GS 450h   NAN      NAN      NAN      NAN
# 9                      Nissan Altima   NAN      NAN      NAN      NAN
# 10                    Lexus LS 600hL   NAN      NAN      NAN      NAN
# 11                        Saturn Vue   NAN      NAN      NAN      NAN
# ...

# %%
US_HEV_SALES.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60 entries, 0 to 59
# Data columns (total 22 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Vehicle  60 non-null     object
#  1   1999     60 non-null     object
#  2   2000     60 non-null     object
#  3   2001     60 non-null     object
#  4   2002     60 non-null     object
#  5   2003     60 non-null     object
#  6   2004     60 non-null     object
#  7   2005     60 non-null     object
#  8   2006     60 non-null     object
#  9   2007     60 non-null     object
#  10  2008     60 non-null     object
#  11  2009     60 non-null     object
#  12  2010     60 non-null     object
#  13  2011     60 non-null     object
#  14  2012     60 non-null     object
#  15  2013     60 non-null     object
#  16  2014     60 non-null     object
#  17  2015     60 non-null     object
#  18  2016     60 non-null     object
#  19  2017     60 non-null     object
# ...

# %%
US_HEV_SALES.isna().sum()
# Out:
# Vehicle    0
# 1999       0
# 2000       0
# 2001       0
# 2002       0
# 2003       0
# 2004       0
# 2005       0
# 2006       0
# 2007       0
# 2008       0
# 2009       0
# 2010       0
# 2011       0
# 2012       0
# 2013       0
# 2014       0
# 2015       0
# 2016       0
# 2017       0
# 2018       0
# 2019       0
# dtype: int64
